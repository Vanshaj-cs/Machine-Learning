# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanshaj-cs/Machine-Learning/blob/main/Hypertuning_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn.datasets
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
breast_cancer_dataset = sklearn.datasets.load_breast_cancer()

# %%
cancer_data = pd.DataFrame(breast_cancer_dataset.data, columns = breast_cancer_dataset.feature_names)

# %%
cancer_data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
cancer_data.shape
# Out:
# (569, 30)

# %%
cancer_data['label'] = breast_cancer_dataset.target

# %%
cancer_data.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# label                      0
# dtype: int64

# %%
cancer_data['label'].value_counts()
# Out:
# label
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
X = cancer_data.drop(columns='label', axis=1)
Y = cancer_data['label']

# %%
 X = np.asarray(X)
 Y = np.asarray(Y)

# %% [markdown]
# GridSearchCV

# %%
model = SVC()

# %%
parameters = {
              'kernel':['linear','poly','rbf','sigmoid'],
              'C':[1, 5, 10, 20]
}

# %%
classifier = GridSearchCV(model, parameters, cv=5)

# %%
classifier.fit(X, Y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 20],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([1.56210022e+00, 3.66845131e-03, 4.37364578e-03, 1.41518593e-02,
#         3.19254398e+00, 6.22286797e-03, 7.02219009e-03, 2.03637600e-02,
#         4.45312519e+00, 4.11448479e-03, 3.93905640e-03, 1.37445927e-02,
#         7.42095137e+00, 4.23760414e-03, 4.36997414e-03, 1.32356644e-02]),
#  'std_fit_time': array([5.76549303e-01, 1.11908063e-04, 9.30732634e-05, 3.50793201e-04,
#         8.25177502e-01, 7.47437471e-04, 7.20478751e-04, 1.85889938e-03,
#         1.08822402e+00, 9.68020067e-05, 1.01209358e-04, 7.00368234e-04,
#         2.36738640e+00, 1.31550756e-04, 8.63275294e-04, 7.41207796e-04]),
#  'mean_score_time': array([0.00162201, 0.00124216, 0.00179734, 0.0038249 , 0.00134168,
#         0.00211201, 0.00301542, 0.0061872 , 0.00118694, 0.00118361,
#         0.00160751, 0.00385499, 0.00136471, 0.00118475, 0.00155139,
#         0.00348887]),
#  'std_score_time': array([3.20135251e-04, 1.39445318e-05, 2.34100336e-05, 7.02673229e-05,
#         2.82547467e-04, 5.47089550e-05, 1.41325927e-04, 1.14068249e-03,
#         1.20966360e-05, 1.75094708e-05, 6.74859529e-05, 4.05166319e-04,
#         2.83227344e-04, 4.72336992e-05, 8.08913166e-05, 6.47202768e-05]),
#  'param_C': masked_array(data=[1, 1, 1, 1, 5, 5, 5, 5, 10, 10, 10, 10, 20, 20, 20, 20],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['linear', 'poly', 'rbf', 'sigmoid', 'linear', 'poly',
#                     'rbf', 'sigmoid', 'linear', 'poly', 'rbf', 'sigmoid',
#                     'linear', 'poly', 'rbf', 'sigmoid'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'linear'},
#   {'C': 1, 'kernel': 'poly'},
#   {'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'sigmoid'},
#   {'C': 5, 'kernel': 'linear'},
#   {'C': 5, 'kernel': 'poly'},
#   {'C': 5, 'kernel': 'rbf'},
#   {'C': 5, 'kernel': 'sigmoid'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'poly'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'sigmoid'},
#   {'C': 20, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'poly'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'sigmoid'}],
#  'split0_test_score': array([0.94736842, 0.84210526, 0.85087719, 0.54385965, 0.94736842,
#         0.88596491, 0.88596491, 0.49122807, 0.93859649, 0.88596491,
#         0.87719298, 0.48245614, 0.92982456, 0.87719298, 0.87719298,
#         0.47368421]),
#  'split1_test_score': array([0.92982456, 0.88596491, 0.89473684, 0.45614035, 0.93859649,
#         0.9122807 , 0.92982456, 0.42105263, 0.93859649, 0.92105263,
#         0.92105263, 0.40350877, 0.95614035, 0.92105263, 0.92105263,
#         0.40350877]),
#  'split2_test_score': array([0.97368421, 0.92982456, 0.92982456, 0.46491228, 0.97368421,
#         0.92105263, 0.93859649, 0.42105263, 0.97368421, 0.90350877,
#         0.9122807 , 0.42105263, 0.95614035, 0.90350877, 0.92105263,
#         0.42105263]),
#  'split3_test_score': array([0.92105263, 0.94736842, 0.94736842, 0.38596491, 0.92982456,
#         0.93859649, 0.94736842, 0.35087719, 0.94736842, 0.93859649,
#         0.95614035, 0.34210526, 0.93859649, 0.93859649, 0.94736842,
#         0.34210526]),
#  'split4_test_score': array([0.95575221, 0.9380531 , 0.9380531 , 0.45132743, 0.96460177,
#         0.95575221, 0.95575221, 0.37168142, 0.96460177, 0.95575221,
#         0.94690265, 0.36283186, 0.96460177, 0.95575221, 0.9380531 ,
#         0.3539823 ]),
#  'mean_test_score': array([0.94553641, 0.90866325, 0.91217202, 0.46044093, 0.95081509,
#         0.92272939, 0.93150132, 0.41117839, 0.95256948, 0.920975  ,
#         0.92271386, 0.40239093, 0.9490607 , 0.91922062, 0.92094395,
#         0.39886664]),
#  'std_test_score': array([0.01868869, 0.03938232, 0.03544367, 0.05025317, 0.01621632,
#         0.02368918, 0.02435811, 0.04857818, 0.01419963, 0.02470123,
#         0.02787898, 0.0489065 , 0.01281637, 0.02730027, 0.02410455,
#         0.0476401 ]),
#  'rank_test_score': array([ 4, 12, 11, 13,  2,  6,  5, 14,  1,  8,  7, 15,  3, 10,  9, 16],
#        dtype=int32)}

# %%
best_parameters = classifier.best_params_
print(best_parameters)
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
highest_accuracy = classifier.best_score_
print(highest_accuracy)
# Out:
# 0.9525694767893185

# %%
result = pd.DataFrame(classifier.cv_results_)
result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       1.562100      0.576549         0.001622        0.000320        1
# 1       0.003668      0.000112         0.001242        0.000014        1
# 2       0.004374      0.000093         0.001797        0.000023        1
# 3       0.014152      0.000351         0.003825        0.000070        1
# 4       3.192544      0.825178         0.001342        0.000283        5
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           0.947368
# 1         poly     {'C': 1, 'kernel': 'poly'}           0.842105
# 2          rbf      {'C': 1, 'kernel': 'rbf'}           0.850877
# 3      sigmoid  {'C': 1, 'kernel': 'sigmoid'}           0.543860
# 4       linear   {'C': 5, 'kernel': 'linear'}           0.947368
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.929825           0.973684           0.921053           0.955752
# 1           0.885965           0.929825           0.947368           0.938053
# 2           0.894737           0.929825           0.947368           0.938053
# 3           0.456140           0.464912           0.385965           0.451327
# 4           0.938596           0.973684           0.929825           0.964602
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.945536        0.018689                4
# 1         0.908663        0.039382               12
# 2         0.912172        0.035444               11
# 3         0.460441        0.050253               13
# 4         0.950815        0.016216                2

# %%
grid_search_result = result[['param_C','param_kernel','mean_test_score']]
grid_search_result
# Out:
#     param_C param_kernel  mean_test_score
# 0         1       linear         0.945536
# 1         1         poly         0.908663
# 2         1          rbf         0.912172
# 3         1      sigmoid         0.460441
# 4         5       linear         0.950815
# 5         5         poly         0.922729
# 6         5          rbf         0.931501
# 7         5      sigmoid         0.411178
# 8        10       linear         0.952569
# 9        10         poly         0.920975
# 10       10          rbf         0.922714
# 11       10      sigmoid         0.402391
# 12       20       linear         0.949061
# 13       20         poly         0.919221
# 14       20          rbf         0.920944
# 15       20      sigmoid         0.398867

# %% [markdown]
# RandomizedSearchCV

# %%
model = SVC()

# %%
parameters = {
              'kernel':['linear','poly','rbf','sigmoid'],
              'C':[1, 5, 10, 20]
}

# %%
classifier = RandomizedSearchCV(model, parameters, cv=5)

# %%
classifier.fit(X, Y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(),
#                    param_distributions={'C': [1, 5, 10, 20],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([5.03559575e+00, 4.04682159e-03, 3.02165036e+00, 1.51967525e-02,
#         1.32737637e-02, 1.32018089e-02, 1.57436371e-02, 4.69903946e-03,
#         4.22854424e-03, 1.57700481e+00]),
#  'std_fit_time': array([1.33449479e+00, 8.77635079e-05, 8.22403419e-01, 1.30826843e-03,
#         5.44876135e-04, 6.48944708e-04, 2.15244263e-03, 4.22147047e-04,
#         1.46836535e-04, 6.19591791e-01]),
#  'mean_score_time': array([0.00126019, 0.00121503, 0.00148959, 0.00397654, 0.00358925,
#         0.00354371, 0.00435839, 0.00197754, 0.00120068, 0.00152435]),
#  'std_score_time': array([4.56805518e-05, 2.70490685e-05, 3.31094874e-04, 4.06139314e-05,
#         6.92459828e-05, 1.00055685e-04, 7.19448352e-04, 1.69596747e-04,
#         2.98634855e-05, 3.30153405e-04]),
#  'param_kernel': masked_array(data=['linear', 'poly', 'linear', 'sigmoid', 'sigmoid',
#                     'sigmoid', 'sigmoid', 'rbf', 'poly', 'linear'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'param_C': masked_array(data=[10, 10, 5, 1, 10, 20, 5, 1, 20, 1],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value=999999),
#  'params': [{'kernel': 'linear', 'C': 10},
#   {'kernel': 'poly', 'C': 10},
#   {'kernel': 'linear', 'C': 5},
#   {'kernel': 'sigmoid', 'C': 1},
#   {'kernel': 'sigmoid', 'C': 10},
#   {'kernel': 'sigmoid', 'C': 20},
#   {'kernel': 'sigmoid', 'C': 5},
#   {'kernel': 'rbf', 'C': 1},
#   {'kernel': 'poly', 'C': 20},
#   {'kernel': 'linear', 'C': 1}],
#  'split0_test_score': array([0.93859649, 0.88596491, 0.94736842, 0.54385965, 0.48245614,
#         0.47368421, 0.49122807, 0.85087719, 0.87719298, 0.94736842]),
#  'split1_test_score': array([0.93859649, 0.92105263, 0.93859649, 0.45614035, 0.40350877,
#         0.40350877, 0.42105263, 0.89473684, 0.92105263, 0.92982456]),
#  'split2_test_score': array([0.97368421, 0.90350877, 0.97368421, 0.46491228, 0.42105263,
#         0.42105263, 0.42105263, 0.92982456, 0.90350877, 0.97368421]),
#  'split3_test_score': array([0.94736842, 0.93859649, 0.92982456, 0.38596491, 0.34210526,
#         0.34210526, 0.35087719, 0.94736842, 0.93859649, 0.92105263]),
#  'split4_test_score': array([0.96460177, 0.95575221, 0.96460177, 0.45132743, 0.36283186,
#         0.3539823 , 0.37168142, 0.9380531 , 0.95575221, 0.95575221]),
#  'mean_test_score': array([0.95256948, 0.920975  , 0.95081509, 0.46044093, 0.40239093,
#         0.39886664, 0.41117839, 0.91217202, 0.91922062, 0.94553641]),
#  'std_test_score': array([0.01419963, 0.02470123, 0.01621632, 0.05025317, 0.0489065 ,
#         0.0476401 , 0.04857818, 0.03544367, 0.02730027, 0.01868869]),
#  'rank_test_score': array([ 1,  4,  2,  7,  9, 10,  8,  6,  5,  3], dtype=int32)}

# %%
best_parameters = classifier.best_params_
print(best_parameters)
# Out:
# {'kernel': 'linear', 'C': 10}

# %%
highest_accuracy = classifier.best_score_
print(highest_accuracy)
# Out:
# 0.9525694767893185

# %%
result = pd.DataFrame(classifier.cv_results_)
result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       5.035596      1.334495         0.001260        0.000046       linear
# 1       0.004047      0.000088         0.001215        0.000027         poly
# 2       3.021650      0.822403         0.001490        0.000331       linear
# 3       0.015197      0.001308         0.003977        0.000041      sigmoid
# 4       0.013274      0.000545         0.003589        0.000069      sigmoid
#
#    param_C                          params  split0_test_score  \
# 0       10   {'kernel': 'linear', 'C': 10}           0.938596
# 1       10     {'kernel': 'poly', 'C': 10}           0.885965
# 2        5    {'kernel': 'linear', 'C': 5}           0.947368
# 3        1   {'kernel': 'sigmoid', 'C': 1}           0.543860
# 4       10  {'kernel': 'sigmoid', 'C': 10}           0.482456
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.938596           0.973684           0.947368           0.964602
# 1           0.921053           0.903509           0.938596           0.955752
# 2           0.938596           0.973684           0.929825           0.964602
# 3           0.456140           0.464912           0.385965           0.451327
# 4           0.403509           0.421053           0.342105           0.362832
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.952569        0.014200                1
# 1         0.920975        0.024701                4
# 2         0.950815        0.016216                2
# 3         0.460441        0.050253                7
# 4         0.402391        0.048906                9

# %%
randomized_search_result = result[['param_C','param_kernel','mean_test_score']]
randomized_search_result
# Out:
#    param_C param_kernel  mean_test_score
# 0       10       linear         0.952569
# 1       10         poly         0.920975
# 2        5       linear         0.950815
# 3        1      sigmoid         0.460441
# 4       10      sigmoid         0.402391
# 5       20      sigmoid         0.398867
# 6        5      sigmoid         0.411178
# 7        1          rbf         0.912172
# 8       20         poly         0.919221
# 9        1       linear         0.945536
